# %%
import pandas as pd
import numpy as np
import re
import json

movies=pd.read_csv('/home/silvia/corsi/Informatica/Python/data_science_foundations/movies/tmdb_5000_movies.csv')
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
credits=pd.read_csv('/home/silvia/corsi/Informatica/Python/data_science_foundations/movies/tmdb_5000_credits.csv')
credits
# Out:
#       movie_id                                        title  \
# 0        19995                                       Avatar
# 1          285     Pirates of the Caribbean: At World's End
# 2       206647                                      Spectre
# 3        49026                        The Dark Knight Rises
# 4        49529                                  John Carter
# 5          559                                 Spider-Man 3
# 6        38757                                      Tangled
# 7        99861                      Avengers: Age of Ultron
# 8          767       Harry Potter and the Half-Blood Prince
# 9       209112           Batman v Superman: Dawn of Justice
# 10        1452                             Superman Returns
# 11       10764                            Quantum of Solace
# 12          58   Pirates of the Caribbean: Dead Man's Chest
# 13       57201                              The Lone Ranger
# 14       49521                                 Man of Steel
# ...

# %%
# For each movie, compute the number of cast members

def extract_cast(x):
    d=json.loads(x)
    if len(d)==0 :
        nc=None
    else :
        nc=pd.DataFrame(d)['cast_id'].count()
    return nc

movies.rename(columns={'id': 'movie_id'}, inplace=True) # inplace rinomina la colonna del database senza farne una copia
movies

cast=movies.merge(credits,on=['movie_id'],suffixes=['',' credits'])[['movie_id','original_title','cast']]
cast

#forse c'è qualche cast nullo e non funzia l'applicazione della funzione
cast['n. cast members']=credits['cast'].apply(lambda row: extract_cast(row) if(pd.notnull(row)) else None)
cast
# Out:
#       movie_id                               original_title  \
# 0        19995                                       Avatar
# 1          285     Pirates of the Caribbean: At World's End
# 2       206647                                      Spectre
# 3        49026                        The Dark Knight Rises
# 4        49529                                  John Carter
# 5          559                                 Spider-Man 3
# 6        38757                                      Tangled
# 7        99861                      Avengers: Age of Ultron
# 8          767       Harry Potter and the Half-Blood Prince
# 9       209112           Batman v Superman: Dawn of Justice
# 10        1452                             Superman Returns
# 11       10764                            Quantum of Solace
# 12          58   Pirates of the Caribbean: Dead Man's Chest
# 13       57201                              The Lone Ranger
# 14       49521                                 Man of Steel
# ...

# %%
# How many movies do not have a homepage?

movies[movies['homepage'].isnull()]
# Out:
#          budget                                             genres homepage  \
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...      NaN
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...      NaN
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...      NaN
# 33    210000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...      NaN
# 34    200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...      NaN
# 47    190000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...      NaN
# 49    105000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...      NaN
# 58    140000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...      NaN
# 63    180000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...      NaN
# 70    170000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...      NaN
# 75    175000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...      NaN
# ...
